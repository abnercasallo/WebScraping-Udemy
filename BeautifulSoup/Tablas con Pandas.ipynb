# %% [markdown]
# # Proyecto : Tablas con Pandas
# Abner Casallo

# %% [markdown]
# En este proyecto mostraremos algunos casos en los que sí se podría obtener tablas de forma rápida solo suando Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Población

# %%
tabla_poblacion = pd.read_html("https://www.worldometers.info/world-population/population-by-country/")
tabla_poblacion[0]
# Out:
#        # Country (or dependency)  Population (2023) Yearly Change  Net Change  \
# 0      1                   India         1428627663        0.81 %    11454490
# 1      2                   China         1425671352       -0.02 %     -215985
# 2      3           United States          339996563        0.50 %     1706706
# 3      4               Indonesia          277534122        0.74 %     2032783
# 4      5                Pakistan          240485658        1.98 %     4660796
# ..   ...                     ...                ...           ...         ...
# 229  230              Montserrat               4386       -0.09 %          -4
# 230  231        Falkland Islands               3791        0.29 %          11
# 231  232                    Niue               1935        0.05 %           1
# 232  233                 Tokelau               1893        1.18 %          22
# 233  234                Holy See                518        1.57 %           8
#
# ...

# %% [markdown]
# ## Covid

# %%
covid = pd.read_html("https://datosmacro.expansion.com/otros/coronavirus")
covid[0]
# Out:
#               Países       Fecha  Incremento Muertos  Muertos  \
# 0         España [+]  19/07/2023                   0  121.852
# 1       Alemania [+]  06/09/2023                   0  174.979
# 2    Reino Unido [+]  06/09/2023                   0  228.924
# 3        Francia [+]  06/09/2023                   0  167.985
# 4         Italia [+]  06/09/2023                   0  191.276
# ..               ...         ...                 ...      ...
# 190        Samoa [+]  06/09/2023                   0       31
# 191        Yemen [+]  06/09/2023                   0    2.159
# 192    Sudáfrica [+]  06/09/2023                   0  102.595
# 193       Zambia [+]  06/09/2023                   0    4.069
# 194     Zimbabue [+]  06/09/2023                   0    5.717
#
#     Muertos / millón  Incremento Confirmados Confirmados  \
# 0           2.520,46                       0  13.980.340
# 1           2.074,22                       0  38.437.756
# ...

# %% [markdown]
# ## Commodities: Petróleo

# %%
d = pd.read_html("https://cincodias.elpais.com/mercados/materias-primas/petroleo_brent/1/")
d[0]
# Out:
#          Fecha  Cierre  Var %  Máximo  Mínimo  Cambio neto
# 0   08-09-2023    9044     58    9102    8930           52
# 1   08-09-2023    9044     58    9102    8930           52
# 2   07-09-2023    8977    -92    9089    8946          -83
# 3   06-09-2023    9066     69    9110    8925           62
# 4   05-09-2023    9002    115    9115    8806          102
# 5   04-09-2023    8900     51    8922    8826           45
# 6   01-09-2023    8894    243    8899    8674          211
# 7   31-08-2023    8683    113    8694    8574           97
# 8   30-08-2023    8595     54    8623    8511           46
# 9   29-08-2023    8551    129    8565    8380          109
# 10  28-08-2023    8435    -15    8523    8411          -13
# 11  25-08-2023    8479    172    8497    8267          143
# 12  24-08-2023    8320     -1    8362    8197           -1
# 13  23-08-2023    8302   -120    8426    8194         -101
# 14  22-08-2023    8387    -70    8466    8385          -59
# ...
